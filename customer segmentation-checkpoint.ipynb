# %% [markdown]
# # CUSTOMER SEGMENTATION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
# Out:
# C:\Users\rnbja\AppData\Roaming\Python\Python39\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#DATA PRE_PROCESSING
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# No missing/null values present

# %%
#EDA
sns.countplot(x='Gender',data=df,hue='Gender')
plt.title("Numbers of Males and Females")
# Out:
# Text(0.5, 1.0, 'Numbers of Males and Females')

# %%
sns.pairplot(df.drop("CustomerID", axis = 1), hue = "Gender")

# %%
sns.boxplot(x = 'Gender', y = "Annual Income (k$)", data = df)
plt.title("Boxplot of Annual Income with Gender")
plt.show()

# %%
# ELBOW METHOD

x=df.iloc[:,[3,4]].values
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
#plotting the graph
plt.plot(range(1,11),wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# optimal clusters=5

# %%
# Applying kmeans to the dataset / Creating the kmeans classifier

kmeans = KMeans(n_clusters = 5, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
#VISUALIZING THE CLUSTERS
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=80,c='black',label='Customer1')
plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],s=80,c='blue',label='Customer2')
plt.scatter(x[y_kmeans==2,0],x[y_kmeans==2,1],s=80,c='yellow',label='Customer3')
plt.scatter(x[y_kmeans==3,0],x[y_kmeans==3,1],s=80,c='grey',label='Customer4')
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=80,c='orange',label='Customer5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=120,c='RED',label='Centroids')
plt.title("Customer Segmentation")
plt.xlabel("Income(k$)")
plt.ylabel('Spending Score(1-100)')
plt.legend()
plt.show()
#plt.plot(centroid_centers_)

# %% [markdown]
# # INSIGHTS!

# %% [raw]
# Customer 2 and customer 3 are our target audience
